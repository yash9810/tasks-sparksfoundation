# %%
# Importing libraries
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
#loading the dataset
data=pd.read_csv("https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv")
data.head()
print(data.describe())
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
#scatter plot

data.plot(x='Hours', y='Scores', style='o')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,1]

# %%
#spitting the given data into training and test sets
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                            test_size=0.2, random_state=0)

# %%
#training the data
from sklearn.linear_model import LinearRegression  
r= LinearRegression()  
r.fit(x_train, y_train) 
line = r.coef_*x+r.intercept_
# Plotting for the test data
plt.scatter(x, y)
plt.plot(x, line);
plt.show()

# %%
#predicting the data and comparing it with actual data
print(x_test) 
y_pred = r.predict(x_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
#     Hours
# 5     1.5
# 2     3.2
# 19    7.4
# 16    2.5
# 11    5.9
#     Actual  Predicted
# 5       20  16.884145
# 2       27  33.732261
# 19      69  75.357018
# 16      30  26.794801
# 11      62  60.491033

# %%
#final prediction
predictedmarks=r.predict([[9.25]])

# %%
print("when they study for 9.25 hrs the marks a student might obtain are",predictedmarks)
# Out:
# when they study for 9.25 hrs the marks a student might obtain are [93.69173249]
